# %% [markdown]
# # Analiza povprečnih dnevnih temperatur (Open-Meteo)
#
# ## 1. Uvod
# V tej projektni nalogi sem raziskala povprečne dnevne temperature v različnih mestih (Ljubljana, Berlin, Pariz) na podlagi podatkov iz <a href="https://open-meteo.com/en/docs" style="color: skyblue;">Open-Meteo</a>.
# Dodatne informacije o projektni nalogi in podrobna navodila najdete na ........

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import grafi

# %% [markdown]
# ## Pridobivanje podatkov
#
# Podatke sem naložila iz datoteke `zgodovina_vsa_mesta.csv`. Spodnja tabela služi za vse nadaljne, saj iz nje beremo naslednje podatke:
# - temperatura,
# - datum,
# - mesto.

# %%
import pandas as pd

df_vsa_mesta = pd.read_csv("podatki/zgodovina_vsa_mesta.csv")

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

df_vsa_mesta
# Out:
#           mesto       datum  Povprečna temperatura (v °C)
# 0     Ljubljana  2024-09-03                          22.3
# 1     Ljubljana  2024-09-04                          22.3
# 2     Ljubljana  2024-09-05                          20.6
# 3     Ljubljana  2024-09-06                          19.5
# 4     Ljubljana  2024-09-07                          20.3
# 5     Ljubljana  2024-09-08                          21.6
# 6     Ljubljana  2024-09-09                          18.8
# 7     Ljubljana  2024-09-10                          17.5
# 8     Ljubljana  2024-09-11                          17.6
# 9     Ljubljana  2024-09-12                          13.5
# 10    Ljubljana  2024-09-13                           9.7
# 11    Ljubljana  2024-09-14                          11.1
# 12    Ljubljana  2024-09-15                          12.8
# 13    Ljubljana  2024-09-16                          12.1
# 14    Ljubljana  2024-09-17                          11.9
# ...

# %% [markdown]
# ## Urejena tabela
# V tem razdelku je podana tabela za lepši prikaz podatkov.

# %%
from grafi import ustvari_pivot_tabelo

ime_datoteke = "podatki/zgodovina_vsa_mesta.csv"

tabela = ustvari_pivot_tabelo(ime_datoteke)

display(tabela)
# Out:
# mesto Datum/mesto  Berlin  Ljubljana  Pārīz
# 0      2024-09-03    24.6       22.3   20.6
# 1      2024-09-04    26.7       22.3   21.1
# 2      2024-09-05    25.8       20.6   22.1
# 3      2024-09-06    24.4       19.5   23.8
# 4      2024-09-07    24.0       20.3   24.1
# 5      2024-09-08    25.8       21.6   23.8
# 6      2024-09-09    19.1       18.8   23.1
# 7      2024-09-10    16.5       17.5   20.3
# 8      2024-09-11    15.1       17.6   19.9
# 9      2024-09-12    12.0       13.5   21.2
# 10     2024-09-13    11.5        9.7   21.9
# 11     2024-09-14    13.7       11.1   22.2
# 12     2024-09-15    13.5       12.8   20.3
# 13     2024-09-16    15.2       12.1   20.1
# 14     2024-09-17    18.5       11.9   21.0
# 15     2024-09-18    18.9       13.4   21.2
# 16     2024-09-19    18.5       15.8   21.0
# 17     2024-09-20    17.4       15.5   20.9
# 18     2024-09-21    16.5       16.0   21.0
# 19     2024-09-22    16.6       15.1   22.4
# ...

# %% [markdown]
# ## Povprečne dnevne temperature
# V spodnjem grafu so prikazane povprečne dnevne temperature za vsako mesto, tekom let 2024 in 2025.

# %%
mesta = ["Ljubljana", "Berlin", "Pārīz"]
grafi.narisi_temperaturni_graf(df_vsa_mesta, izbrana_mesta=mesta)

# %% [markdown]
# ## Osnovna statistika
# Tabela podaja minimalno, maksimalno in povprečno temperaturo ter standardni odmik za vsako mesto.

# %%
stat = grafi.statistika_mest(df_vsa_mesta)

stat = stat.rename(columns={
    "min": "min.",
    "max": "maks.",
    "mean": "povp.",
    "std": "std. odm."
})

stat.loc[mesta]
# Out:
#            min.  maks.  povp.  std. odm.
# mesto
# Ljubljana  -2.5   27.8  11.35       8.18
# Berlin     -7.4   29.7  10.95       7.48
# Pārīz      -6.9   29.4  15.23       9.06

# %% [markdown]
# ## Sezonska analiza
# Prikazala sem tudi povprečne temperature glede na letni čas v tabeli in s stolpčnim diagramom.

# %%
sezonski_povprecji = grafi.sezonska_analiza(df_vsa_mesta)
sezonski_povprecji.loc[mesta]
# Out:
# Letni čas  Jesen  Poletje  Pomlad  Zima
# mesto
# Ljubljana  11.00    21.65   10.87  1.65
# Berlin     11.35    19.37   10.66  2.24
# Pārīz      16.50    25.04   16.15  2.98

# %%
sezonski_povprecji = grafi.sezonska_analiza(df_vsa_mesta)
sezonski_povprecji.loc[mesta]

grafi.prikazi_stolpicni_diagram_letni_casi(sezonski_povprecji, mesta)
